# %%
from pycaret.classification import *
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Funciones de monitoreo

# %%
def calcular_psi(serie_original, serie_nueva, bins=10):
    # Esta es una función de ejemplo para calcular el PSI
    # Deberías adaptarla según tus necesidades específicas
    conteo_original, _ = np.histogram(serie_original, bins=bins)
    conteo_nuevo, _ = np.histogram(serie_nueva, bins=bins)
    psi_values = np.where(conteo_original == 0, 0, (conteo_nuevo - conteo_original) / conteo_original) ** 2
    return np.sum(psi_values)

# %%
def monitoring_num_vars(data:pd.DataFrame, var_group, f_ini, f_fin) -> None:
    data_filtrado = data[(data[var_group] >= f_ini) & (data[var_group] <= f_fin)]

    # Calcular la tasa de variación, PSI (requiere implementación adicional), y desviación estándar
    resultados = pd.DataFrame(index=data.columns)

    # Tasa de variación (Ejemplo simplificado, adaptar según sea necesario)
    resultados['tasa_variacion'] = (data_filtrado.groupby(var_group).mean().pct_change().iloc[-1] * 100).fillna(0)

    # Desviación estándar
    resultados['desviacion_estandar'] = data_filtrado.std()
    
    # Calculo PSI
    for col in data.columns:
        resultados.loc[col, 'psi'] = calcular_psi(data[data[var_group] == f_ini][col],
                                                data[data[var_group] == f_fin][col])

    return resultados

# %%
def monitoring_cat_vars(data: pd.DataFrame, vars: list, var_group: list, f_ini: str, f_fin: str) -> None:
    # Filtrar el DataFrame por el rango de fechas
    data_filtered = data[(data[var_group] >= f_ini) & (data[var_group] <= f_fin)]
    
    # Iterar sobre cada variable categórica en var_group
    for var in vars:
        print(f"Análisis de la variable: {var}")
        
        # Agrupar por la variable categórica y contar registros
        counts_before = data_filtered[data_filtered[var_group] == f_ini].groupby(var).size()
        counts_after = data_filtered[data_filtered[var_group] == f_fin].groupby(var).size()
        
        # Comparar los conteos antes y después para cada categoría
        comparison_df = pd.DataFrame({'Antes': counts_before, 'Después': counts_after})
        comparison_df['Variación'] = comparison_df['Después'] - comparison_df['Antes']
        
        # Mostrar los resultados
        print(comparison_df)
        print("\n")  # Añadir una línea en blanco entre los análisis de cada variable

# %% [markdown]
# ## Ejecución Ejemplo

# %%
data  = pd.read_csv("monitoring_example.csv")
data.head()
# Out:
#    nit_enmascarado  num_oblig_enmascarado  num_oblig_orig_enmascarado  \
# 0            61793                 580684                      499658
# 1           229509                 483252                      597090
# 2           263991                 746818                      333761
# 3           434373                   4039                     1076303
# 4           379328                 577317                      503025
#
#    fecha_var_rpta_alt  var_rpta_alt            marca_pago ajustes_banco  lote  \
# 0              202401           NaN  FACTURACION_MES_SGTE            NO     2
# 1              202312           0.0               NO_PAGO            NO     3
# 2              202312           1.0            PAGO_MENOS            NO     1
# 3              202401           NaN            PAGO_MENOS            NO     2
# 4              202401           NaN               NO_PAGO            NO     1
#
#    avg_sld_cap_final_1  avg_sld_cap_final_stddev_ult3  ...  prob_propension_1  \
# 0         1.809671e+06                   16154.520176  ...           0.925839
# 1         9.648590e+05                     536.884826  ...           0.910972
# 2         1.182593e+07                   59862.688105  ...           0.707389
# 3         4.087871e+06                       0.000000  ...           0.461028
# 4         5.000845e+06                       0.000000  ...           0.581595
#
#    prob_propension_stddev_ult3  prob_propension_stddev_ult6  \
# 0                     0.003060                     0.002408
# 1                     0.004644                     0.026044
# 2                     0.060488                     0.047178
# 3                     0.137048                     0.145342
# 4                     0.130925                     0.119128
#
#    prob_propension_max_ult6  prob_alrt_temprana_1  \
# 0                  0.925839              0.378441
# 1                  0.921502              0.163812
# 2                  0.839524              0.551831
# 3                  0.892483              0.718311
# 4                  0.925459              0.617891
#
#    prob_alrt_temprana_stddev_ult3  prob_alrt_temprana_stddev_ult6  \
# 0                        0.091614                        0.085733
# 1                        0.044245                        0.033903
# 2                        0.130113                        0.106325
# 3                        0.030133                        0.135440
# 4                        0.224445                        0.199087
#
#    prob_auto_cura_1  prob_auto_cura_stddev_ult3  prob_auto_cura_stddev_ult6
# 0          0.622551                    0.013563                    0.056557
# 1          0.828343                    0.005885                    0.005462
# 2          0.310606                    0.053850                    0.051710
# 3          0.217583                    0.047001                    0.135671
# 4          0.261496                    0.240356                    0.214561
#
# [5 rows x 42 columns]

# %%
data_num_monitoring = data.drop(columns=["nit_enmascarado",
                                         "num_oblig_enmascarado",
                                         "num_oblig_orig_enmascarado",
                                         "var_rpta_alt",
                                         "marca_pago",
                                         "ajustes_banco",
                                         "lote"])
cat_vars = ["marca_pago",
            "ajustes_banco",
            "lote"]

# %%
monitoring_num_vars(data_num_monitoring, "fecha_var_rpta_alt", 202312, 202401)
# Out:
#                                    tasa_variacion  desviacion_estandar  \
# fecha_var_rpta_alt                            NaN         4.442846e+01
# avg_sld_cap_final_1                      1.034826         2.372124e+07
# avg_sld_cap_final_stddev_ult3           17.265766         2.122726e+06
# avg_sld_cap_final_stddev_ult6            3.817695         5.325889e+06
# avg_nueva_altura_mora_1                 -6.563946         2.618273e+01
# avg_nueva_altura_mora_stddev_ult3       -1.881330         9.719990e+00
# min_vlr_obligacion_stddev_ult3          -0.239754         3.974945e+06
# avg_vlr_vencido_1                       -3.547942         1.628561e+06
# valor_cuota_mes_1                        1.463419         2.391458e+06
# valor_cuota_mes_stddev_ult3             -2.442920         7.194925e+05
# valor_cuota_mes_stddev_ult6             -1.808831         9.343427e+05
# pago_total_1                            34.105185         8.414846e+06
# pago_total_avg_ult3                     18.162504         6.127285e+06
# porc_pago_1                             35.645779         1.670659e+03
# porc_pago_avg_ult3                     -99.574885         2.307604e+07
# total_ing_1                            -47.527713         5.270483e+09
# total_ing_avg_ult3                     -70.926925         9.897472e+09
# total_ing_stddev_ult3                  -97.357896         5.924237e+09
# tot_activos_1                          -11.291994         3.412103e+10
# tot_activos_stddev_ult3                -24.458515         4.149062e+07
# tot_activos_stddev_ult6                -95.497078         8.732351e+09
# egresos_mes_1                          -40.770094         1.985687e+10
# egresos_mes_stddev_ult3                -94.701199         7.522627e+08
# tot_patrimonio_stddev_ult3             541.961150         8.188594e+09
# tot_patrimonio_stddev_ult6             -72.316584         1.466552e+10
# prob_propension_1                        1.249233         2.092104e-01
# prob_propension_stddev_ult3              3.567319         7.895140e-02
# prob_propension_stddev_ult6              0.539453         1.094190e-01
# prob_propension_max_ult6                 0.285043         1.213311e-01
# prob_alrt_temprana_1                     0.403065         1.761010e-01
# prob_alrt_temprana_stddev_ult3           2.106127         6.287331e-02
# prob_alrt_temprana_stddev_ult6           0.121987         7.475973e-02
# prob_auto_cura_1                         1.591643         2.058769e-01
# prob_auto_cura_stddev_ult3               1.028114         7.766959e-02
# prob_auto_cura_stddev_ult6              -1.096114         9.374082e-02
#
#                                             psi
# fecha_var_rpta_alt                 1.446476e-02
# avg_sld_cap_final_1                4.642107e+00
# avg_sld_cap_final_stddev_ult3      6.875110e+00
# avg_sld_cap_final_stddev_ult6      1.618952e+00
# avg_nueva_altura_mora_1            4.655151e+06
# avg_nueva_altura_mora_stddev_ult3  1.969179e+02
# min_vlr_obligacion_stddev_ult3     1.638887e+00
# avg_vlr_vencido_1                  9.215330e+00
# valor_cuota_mes_1                  1.479013e+02
# valor_cuota_mes_stddev_ult3        1.381234e+02
# valor_cuota_mes_stddev_ult6        2.137414e+02
# pago_total_1                       1.863948e+00
# pago_total_avg_ult3                4.440961e+00
# porc_pago_1                        3.174482e+00
# porc_pago_avg_ult3                 1.446505e-02
# total_ing_1                        1.701445e+01
# total_ing_avg_ult3                 1.701446e+01
# total_ing_stddev_ult3              1.444830e-02
# tot_activos_1                      1.264466e+00
# tot_activos_stddev_ult3            3.941950e+00
# tot_activos_stddev_ult6            4.264320e+00
# egresos_mes_1                      2.014491e+00
# egresos_mes_stddev_ult3            2.644558e-01
# tot_patrimonio_stddev_ult3         2.644677e-01
# tot_patrimonio_stddev_ult6         3.014476e+00
# prob_propension_1                  3.611342e-01
# prob_propension_stddev_ult3        1.810779e+00
# prob_propension_stddev_ult6        1.046057e+00
# prob_propension_max_ult6           3.457348e-01
# prob_alrt_temprana_1               1.964022e-01
# prob_alrt_temprana_stddev_ult3     5.088066e+00
# prob_alrt_temprana_stddev_ult6     1.811277e-01
# prob_auto_cura_1                   1.202401e+00
# prob_auto_cura_stddev_ult3         3.198875e+00
# prob_auto_cura_stddev_ult6         7.843004e-01

# %%
monitoring_cat_vars(data, cat_vars, "fecha_var_rpta_alt", 202312, 202401)
# Out:
# Análisis de la variable: marca_pago
#                       Antes  Después  Variación
# marca_pago
# CANCELADO              1413      141      -1272
# FACTURACION_MES_SGTE  14796    32193      17397
# IGUAL                   249      131       -118
# NO_DATA                 117      195         78
# NO_PAGO               36192    32824      -3368
# PAGO_MAS                227      145        -82
# PAGO_MENOS            47472    46920       -552
#
#
# Análisis de la variable: ajustes_banco
#                 Antes  Después  Variación
# ajustes_banco
# NO             100349   112354      12005
# NO_DATA           117      195         78
#
#
# Análisis de la variable: lote
#       Antes  Después  Variación
# lote
# -99     396      260       -136
#  1    58034    63402       5368
#  2    31548    37176       5628
#  3    10488    11711       1223
